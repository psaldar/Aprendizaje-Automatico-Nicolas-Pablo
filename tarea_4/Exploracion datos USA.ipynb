# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler

# %%
data = pd.read_csv('data/Data_segmentacion_proc.csv')
X = data.drop(columns = ['Id','Id2','Geography'])

scaler = MinMaxScaler()
X_z = scaler.fit_transform(X[X.columns[:50]])

# %%
pca = PCA(n_components= 2)
Z = pca.fit_transform(X_z)

# %%
plt.scatter(X_z[:,0],X_z[:,10])
