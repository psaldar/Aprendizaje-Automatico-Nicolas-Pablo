# %%
# %matplotlib notebook

# %%
import numpy as np
import pandas as pd
from random import randint
import matplotlib.pyplot as plt

# %%
info_umbrales = pd.read_csv('data/sim_umbrales.csv', sep =',')

info_test = pd.read_csv('data/sim_umbrales_test.csv', sep =',')

# %%
porcentajes = [0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]
data = info_umbrales.drop(columns = '0').values

# %%
n,m = data.shape

# %%
B = 1000
lower_bound = []
upper_bound = []
for i in range(m):
    res_var = []
    info_aux = data[:,i]
    for b in range(B):
        idx = randint(0,m-1)
        data_aux_rm = np.delete(info_aux, idx)
        res_var.append(data_aux_rm.mean())
    lower_bound.append(np.percentile(res_var,2.5))
    upper_bound.append(np.percentile(res_var,97.5))

# %%
summary = pd.DataFrame()
summary['lower_bound'] = lower_bound
summary['upper_bound'] = upper_bound
summary['test'] = info_test
summary['Porcentajes'] = porcentajes

# %%
ax = summary.plot(x='Porcentajes')
# Out:
# <img src="data:image/png;base64,..." width="949.6">

# %%
summary
# Out:
#     lower_bound  upper_bound      test  Porcentajes
# 0      0.727877     0.728176  0.709053          0.0
# 1      0.727667     0.727862  0.710996          0.5
# 2      0.727742     0.728012  0.713986          1.0
# 3      0.727542     0.727713  0.712629          1.5
# 4      0.727556     0.727709  0.714518          2.0
# 5      0.727198     0.727352  0.713179          2.5
# 6      0.726194     0.726324  0.714384          3.0
# 7      0.726444     0.726649  0.713151          3.5
# 8      0.725379     0.725688  0.713273          4.0
# 9      0.724833     0.725023  0.713704          4.5
# 10     0.724264     0.724572  0.712938          5.0
